# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpitaDeshmukh2024/SPPU_DSBDA_Practicals/blob/main/3/DSBDA_Assign3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c8e6dae-48b9-4e83-9142-e5feaf97e900" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c8e6dae-48b9-4e83-9142-e5feaf97e900">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import io

# %%
data = pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# **Datatypes of dataset**

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# **Description of dataset**

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **Mean of dataset**

# %%
data.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %% [markdown]
# **Median of the dataset**

# %%
data.groupby('Species').median()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5            5.0           3.4           1.50
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %% [markdown]
# **Mode(column) of the dataset**

# %%
data.mode(axis = 1, numeric_only = True)
# Out:
#        0    1    2    3      4
# 0    0.2  1.0  1.4  3.5    5.1
# 1    0.2  1.4  2.0  3.0    4.9
# 2    0.2  1.3  3.0  3.2    4.7
# 3    0.2  1.5  3.1  4.0    4.6
# 4    5.0  NaN  NaN  NaN    NaN
# ..   ...  ...  ...  ...    ...
# 145  2.3  3.0  5.2  6.7  146.0
# 146  1.9  2.5  5.0  6.3  147.0
# 147  2.0  3.0  5.2  6.5  148.0
# 148  2.3  3.4  5.4  6.2  149.0
# 149  1.8  3.0  5.1  5.9  150.0
#
# [150 rows x 5 columns]

# %%
data.mode(axis = 1, numeric_only = False)
# Out:
# <ipython-input-11-2868a0ecd96c>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   data.mode(axis = 1, numeric_only = False)
# <ipython-input-11-2868a0ecd96c>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   data.mode(axis = 1, numeric_only = False)
#        0    1    2    3    4               5
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa
# 3      4  4.6  3.1  1.5  0.2     Iris-setosa
# 4      5  NaN  NaN  NaN  NaN             NaN
# ..   ...  ...  ...  ...  ...             ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# **Mode(row) of the dataset**
#
# numeric_only=True is specified, so only the numeric columns are considered, and any non-numeric columns are excluded from the summary statistics.

# %%
data.mode(axis = 0, numeric_only = True)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
# [150 rows x 5 columns]

# %%
data.mode(axis = 0, numeric_only = False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %% [markdown]
# **Standard deviation of the dataset**

# %%
data.groupby('Species').std()
# Out:
#                        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa      14.57738       0.352490      0.381024       0.173511
# Iris-versicolor  14.57738       0.516171      0.313798       0.469911
# Iris-virginica   14.57738       0.635880      0.322497       0.551895
#
#                  PetalWidthCm
# Species
# Iris-setosa          0.107210
# Iris-versicolor      0.197753
# Iris-virginica       0.274650

# %% [markdown]
# **Variance of the dataset**
#
# variance = square of standard deviation

# %%
data.groupby('Species').var()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa      212.5       0.124249      0.145180       0.030106
# Iris-versicolor  212.5       0.266433      0.098469       0.220816
# Iris-virginica   212.5       0.404343      0.104004       0.304588
#
#                  PetalWidthCm
# Species
# Iris-setosa          0.011494
# Iris-versicolor      0.039106
# Iris-virginica       0.075433

# %% [markdown]
# **Minimum of the dataset**

# %%
data.groupby('Species').min()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            4.3           2.3            1.0           0.1
# Iris-versicolor   51            4.9           2.0            3.0           1.0
# Iris-virginica   101            4.9           2.2            4.5           1.4

# %% [markdown]
# **Maximum of the dataset**

# %%
data.groupby('Species').max()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       50            5.8           4.4            1.9           0.6
# Iris-versicolor  100            7.0           3.4            5.1           1.8
# Iris-virginica   150            7.9           3.8            6.9           2.5
